# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt

# %%
df = pd.read_csv('Cities with the Best Work-Life Balance 2022.csv')

# %%
df
# Out:
#     2022 2021          City       Country Remote Jobs Overworked Population  \
# 0      1    2          Oslo        Norway      41.72%                11.20%
# 1      2    -          Bern   Switzerland      44.86%                11.40%
# 2      3    1      Helsinki       Finland      38.92%                12.70%
# 3      4    3        Zurich   Switzerland      44.86%                11.90%
# 4      5    5    Copenhagen       Denmark      41.42%                10.50%
# ..   ...  ...           ...           ...         ...                   ...
# 95    96   49       Bangkok      Thailand      16.84%                15.10%
# 96    97   47     Sao Paulo        Brazil      25.65%                11.80%
# 97    98   50  Kuala Lumpur      Malaysia      30.70%                17.10%
# 98    99    -         Dubai           UAE      28.89%                23.40%
# 99   100    -     Cape Town  South Africa      26.06%                14.80%
#
# ...

# %%
df.dtypes
# Out:
# 2022                                  int64
# 2021                                 object
# City                                 object
# Country                              object
# Remote Jobs                          object
# Overworked Population                object
# Minimum Vacations Offered (Days)      int64
# Vacations Taken (Days)               object
# Unemployment                        float64
# Multiple Jobholders                  object
# Inflation                            object
# Paid Parental Leave (Days)           object
# Covid Impact                        float64
# Covid Support                       float64
# Healthcare                          float64
# Access to Mental Healthcare         float64
# Inclusivity & Tolerance             float64
# Affordability                       float64
# Happiness, Culture & Leisure        float64
# City Safety                         float64
# Outdoor Spaces                      float64
# ...

# %%
# We are gonna remove special characters using replace function

# %%
df.dtypes
# Out:
# 2022                                  int64
# 2021                                 object
# City                                 object
# Country                              object
# Remote Jobs                          object
# Overworked Population                object
# Minimum Vacations Offered (Days)      int64
# Vacations Taken (Days)               object
# Unemployment                        float64
# Multiple Jobholders                  object
# Inflation                            object
# Paid Parental Leave (Days)           object
# Covid Impact                        float64
# Covid Support                       float64
# Healthcare                          float64
# Access to Mental Healthcare         float64
# Inclusivity & Tolerance             float64
# Affordability                       float64
# Happiness, Culture & Leisure        float64
# City Safety                         float64
# Outdoor Spaces                      float64
# ...

# %%
# for i in df.columns:
#     print(i,df[i].unique())

# %%
objectcolumns = list(df.select_dtypes(include = ['object']).columns)

# %%
df = df.replace('[%]','',regex=True)

# %%
df = df.replace('-','0')

# %%
df
# Out:
#     2022 2021          City       Country Remote Jobs Overworked Population  \
# 0      1    2          Oslo        Norway       41.72                 11.20
# 1      2    0          Bern   Switzerland       44.86                 11.40
# 2      3    1      Helsinki       Finland       38.92                 12.70
# 3      4    3        Zurich   Switzerland       44.86                 11.90
# 4      5    5    Copenhagen       Denmark       41.42                 10.50
# ..   ...  ...           ...           ...         ...                   ...
# 95    96   49       Bangkok      Thailand       16.84                 15.10
# 96    97   47     Sao Paulo        Brazil       25.65                 11.80
# 97    98   50  Kuala Lumpur      Malaysia       30.70                 17.10
# 98    99    0         Dubai           UAE       28.89                 23.40
# 99   100    0     Cape Town  South Africa       26.06                 14.80
#
# ...

# %%
for i in objectcolumns:
    try:
        df[i] = df[i].astype(float)
    except:
        df[i] = pd.Categorical(df[i])
        df[i] = df[i].cat.codes
#         df.drop(i,axis=1,inplace=True)

# %%
df.dtypes
# Out:
# 2022                                  int64
# 2021                                float64
# City                                   int8
# Country                                int8
# Remote Jobs                         float64
# Overworked Population               float64
# Minimum Vacations Offered (Days)      int64
# Vacations Taken (Days)              float64
# Unemployment                        float64
# Multiple Jobholders                 float64
# Inflation                           float64
# Paid Parental Leave (Days)             int8
# Covid Impact                        float64
# Covid Support                       float64
# Healthcare                          float64
# Access to Mental Healthcare         float64
# Inclusivity & Tolerance             float64
# Affordability                       float64
# Happiness, Culture & Leisure        float64
# City Safety                         float64
# Outdoor Spaces                      float64
# ...

# %%
x = df.drop('TOTAL SCORE',axis=1)

# %%
x
# Out:
#     2022  2021  City  Country  Remote Jobs  Overworked Population  \
# 0      1   2.0    68       18        41.72                   11.2
# 1      2   0.0     9       25        44.86                   11.4
# 2      3   1.0    38        7        38.92                   12.7
# 3      4   3.0    99       25        44.86                   11.9
# 4      5   5.0    24        6        41.42                   10.5
# ..   ...   ...   ...      ...          ...                    ...
# 95    96  49.0     6       26        16.84                   15.1
# 96    97  47.0    81        4        25.65                   11.8
# 97    98  50.0    45       15        30.70                   17.1
# 98    99   0.0    29       27        28.89                   23.4
# 99   100   0.0    16       21        26.06                   14.8
#
#     Minimum Vacations Offered (Days)  Vacations Taken (Days)  Unemployment  \
# 0                                 25                    25.0          94.7
# ...

# %%
y = df['TOTAL SCORE']

# %%
y
# Out:
# 0     100.00
# 1      99.46
# 2      99.24
# 3      96.33
# 4      96.21
#        ...
# 95     70.73
# 96     66.57
# 97     66.02
# 98     61.23
# 99     50.00
# Name: TOTAL SCORE, Length: 100, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,train_size = 0.8)

# %%
xtrain
# Out:
#     2022  2021  City  Country  Remote Jobs  Overworked Population  \
# 9     10   7.0    62        9        36.73                   11.9
# 58    59  38.0    65       29        41.96                   11.9
# 99   100   0.0    16       21        26.06                   14.8
# 86    87  44.0    41       29        37.33                   13.7
# 55    56   0.0    89       29        39.94                   12.5
# ..   ...   ...   ...      ...          ...                    ...
# 2      3   1.0    38        7        38.92                   12.7
# 89    90  41.0    64       29        41.57                   13.3
# 95    96  49.0     6       26        16.84                   15.1
# 15    16   8.0    94        5        37.81                   10.1
# 54    55   0.0    22       29        40.31                   11.9
#
#     Minimum Vacations Offered (Days)  Vacations Taken (Days)  Unemployment  \
# 9                                 20                    26.0          95.6
# ...

# %%
xtest
# Out:
#     2022  2021  City  Country  Remote Jobs  Overworked Population  \
# 64    65   0.0    43       29        36.61                   12.5
# 74    75  42.0    20       29        31.31                   12.4
# 75    76   0.0    66       29        37.34                   12.4
# 39    40  21.0    12        3        42.34                   12.9
# 42    43   0.0    67       29        38.90                   12.2
# 7      8  10.0    88        1        38.79                    9.7
# 19    20   0.0    33        9        36.73                   11.6
# 46    47   0.0    96       29        34.64                   11.7
# 0      1   2.0    68       18        41.72                   11.2
# 34    35   0.0    60       29        41.14                   13.0
# 90    91   0.0    85       29        37.59                   12.8
# 30    31   0.0    54       28        43.50                   12.9
# 23    24   0.0    49       28        43.50                   12.8
# ...

# %%
ytrain
# Out:
# 9     93.65
# 58    84.23
# 99    50.00
# 86    79.89
# 55    84.31
#       ...
# 2     99.24
# 89    79.11
# 95    70.73
# 15    92.23
# 54    84.56
# Name: TOTAL SCORE, Length: 80, dtype: float64

# %%
ytest
# Out:
# 64     83.33
# 74     81.81
# 75     81.75
# 39     87.18
# 42     86.01
# 7      94.04
# 19     91.06
# 46     85.30
# 0     100.00
# 34     88.09
# 90     77.15
# 30     89.10
# 23     90.68
# 21     90.83
# 35     87.83
# 6      95.51
# 78     81.46
# 26     89.74
# 31     88.38
# 38     87.34
# Name: TOTAL SCORE, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypredict = model.predict(xtest)

# %%
ypredict
# Out:
# array([83.44698097, 82.27606355, 81.59147645, 87.83908987, 86.35546509,
#        94.97576848, 90.85498749, 85.88921995, 98.91316363, 88.54474807,
#        76.41524717, 89.41020078, 91.18395505, 90.25946236, 88.22495176,
#        95.69821423, 81.45738641, 89.99093019, 89.07890049, 87.40429891])

# %%
ytest
# Out:
# 64     83.33
# 74     81.81
# 75     81.75
# 39     87.18
# 42     86.01
# 7      94.04
# 19     91.06
# 46     85.30
# 0     100.00
# 34     88.09
# 90     77.15
# 30     89.10
# 23     90.68
# 21     90.83
# 35     87.83
# 6      95.51
# 78     81.46
# 26     89.74
# 31     88.38
# 38     87.34
# Name: TOTAL SCORE, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
print((r2_score(ypredict,ytest)*100).round(2),'%')
# Out:
# 98.99 %
